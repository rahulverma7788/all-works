# %%
import pandas as pd
import nltk
import numpy as np
import re

# %%
path = 'cleaned_data.tsv'

# %%
df = pd.read_csv('C:/Users/HP/Desktop/data main.csv')
df.tail()
# Out:
#                                                    Text  Class 1
# 8447  mister war is a serious business if you believ...        0
# 8448  when a woman is dicmatized it s nothing her fr...        0
# 8449  pakistan pm imran khan all wars in world histo...        0
# 8450  since when do you have to pass laws against so...        0
# 8451  trust me you will regret it later if one of th...        0

# %%
df.head()
# Out:
#                                                 Text  Class 1
# 0  i m shattered i m at chiromo mortuary and we h...        0
# 1  we are now heading for the game of chicken end...        0
# 2  you know what else is shit about the tech indu...        0
# 3  laverokbirdfood bluefrogtoys peacockspro jjeve...        0
# 4  reposting please refrain from sharing videos o...        0

# %%
df.shape
# Out:
# (8452, 2)

# %%
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
customStopwords = {'a','are','about','above','after','again','against','ain','all','am','an','any','aren',"aren't",'as',
                   'at','be','because','been','before','being','below','between','both','but','by',
                   'can','couldn',"couldn't",'d','didn',"didn't",'do','does','doesn',"doesn't",'doing','don',"don't",
                   'down','during','each','few','for','from','further','had','hadn',"hadn't",'has','hasn',"hasn't",
                   'have','haven',"haven't",'having','he','her','here','hers','herself','him','himself','his','how', 'i','if', 
                   'in', 'into','is','isn',"isn't", "it's",'its','itself','just','ll','m','ma','me','mightn',"mightn't",
                   'more','most','mustn',"mustn't",'my','myself','needn',"needn't",'no','nor','not','now', 'o','of',
                   'off','on','once','only','or','other','our','ours','ourselves','out','over','own','re','s','same',
                   'shan',"shan't",'she',"she's",'should',"should've",'shouldn',"shouldn't",'so','some','such','t','than','that',"that'll",
                   'the','there',"there's",'their','theirs','them','themselves','then','these','they','this','those','through','to','too',
                   'under','until','up','ve','very','was','wasn',"wasn't",'we','were','weren',"weren't",'what','when',
                   'where','which','while','who','whom','why','will','with','won',"won't",'wouldn', "wouldn't",'y',
                   'you',"you'd","you'll","you're","you've",'your','yours','yourself','yourselves'}

# %%
preprocessed_data = []
def preprocess(dataframe):
    for i in range(dataframe.shape[0]):
        df = re.sub('[^a-zA-Z]',' ',dataframe.iloc[i][0]) ##remove all the characters except alphabets (E.g. &, *, #)
        df = df.lower() ## convert all the sentences to lower case
        df = df.split() ##tokenize each word
        df = [word for word in df if word not in customStopwords] ##removing stopwords
        lemmatizer = WordNetLemmatizer()
        df = [lemmatizer.lemmatize(word) for word in df] ##performed lemmatization 
        df = ' '.join(df)
        preprocessed_data.append(df)
    return preprocessed_data

# %%
preprocessed_data = preprocess(df)
preprocessed_data
# Out:
# ['shattered chiromo mortuary and positively identified body abdalla and feisal two good',
#  'heading game chicken end game inevitable it became apparent brexiters actua',
#  'know else shit tech industry nothing designed multilinguals mind long w',
#  'laverokbirdfood bluefrogtoys peacockspro jjeventbars gingerwebltd mine never liked rain it cha',
#  'reposting please refrain sharing video suicide self harm it trigger u suffering mental illne',
#  'time likely killed opioid death gun guess shoot hole take',
#  'hate always present somebody else need help expect much also',
#  'hotel terror attack surveillance footage show several armed men approaching hotel nairobi kenya gunfire eru',
#  'hayyyy',
#  'absolutely agree housing affordability still top anxiety many people filling form nothing need',
#  'ending bst mv',
#  'mbuhari borrowing fund large scale infrastructure project gej h e peter obi served hon special advis',
#  'australianopen great approach net way short it suicidal level',
#  'obviously takeaway got money need worry problem arising due',
#  'somebody responded dr seuss marrying mistress wife committed suicide bitch bitch dead bitch',
#  'jeff session smartest man trumpworld spent second trump wh realized',
#  'sometimes avoid thing love would rather stop pain loss feel moment joy may',
#  'actually tired bro like bottom heart tired',
#  'cant help coming south africa live yu',
#  'warning webtoon graphic and contains sensitive topic like suicide violence death and blood',
#  'moment russia and assad took patrolling manbij trump go ahead get hit suicide bomber first',
#  'ok confirmed k sub end debate sub twitch',
#  'thought everyone spoke different language heard language english',
#  'pelosi asked trump reschedule address deliver it writing long government remains shut',
#  'winning really hurt',
#  'and president trump rejected proposal would prevented ended',
#  'abating suicide army man declaring kulbhushan jadhav india spy sheer hatred hindu festival and',
#  'deathrun allready hate come watch',
#  'sick and tired way going quit',
#  'girl hijab take note ya friend got hair pic leaked best friend',
#  'tired hearing un global goal formulated and belong u and ne',
#  'warning webtoon graphic and contains sensitive topic like suicide violence death and blood',
#  'someday page life end know one beautiful chapter',
#  'warning webtoon graphic and contains sensitive topic like suicide violence death and blood',
#  'remember calling one time felt like life meaningless could stand anything anymore thank',
#  'morning routine includes minute sitting bed and thinking tired',
#  'day like today would make anyone else commit suicide used cry feel urge kill criminal downstair',
#  'really love sunflower post malone and swae lee and finally decided youtube video and it nothing int',
#  'realize day started fuck it need end already last day jhb thank goodness',
#  'le person panic attack intrusive thought suicidal thought anxiety',
#  'totally argue removing player choice order achieve epic story undermines power intera',
#  'it love',
#  'hate people say oh committed suicide selfish could leave friend and family',
#  'girl committed suicide jumping front train video sex football team leaked someon',
#  'suicide hotlines always get shared recent news someone passing side note like always check',
#  'might fuck around and kill',
#  'end shutdown crisis want make american great let people',
#  'yo imagine obama did ghetto shit like would never heard end it',
#  'it wattpad story thing person put band lyric google translate f',
#  'umm yelled cuz kill everybody gas station',
#  'actually tired bro like bottom heart tired',
#  'end it already done punishing yet',
#  'high suicide energy reach end degree capricorn pluto conjuncts mercury please know darkness',
#  'could get gf end life',
#  'actually tired bro like bottom heart tired',
#  'jin face cracking thing end blood seeat tear standing front mirror it happened',
#  'send condolence family and friend mr brian velasco depression serious health issue and ne',
#  'live world people want others validate and accept exactly external validation',
#  'warning webtoon graphic and contains sensitive topic like suicide violence death and blood',
#  'warning webtoon graphic and contains sensitive topic like suicide violence death and blood',
#  'gonna realize it business and coach going swear and keep happy it',
#  'honestly stop know wrong cultural reaction',
#  'nobody know boy reason happy alive and actually want eart',
#  'literally nobody medium liberal want rename sun daughter somebody uncle going',
#  'asshole and refrain sharing video brian velasco it trigger people suicidal tend',
#  'jesus christ side nothing fear',
#  'life hate want freaking read it refuse load really want read ipad ughhhhhg http',
#  'jin face cracking thing end blood seeat tear standing front mirror it happened',
#  'high time congress jds stop poaching mla start working state every day annadathas co',
#  'ever lost respect someone hate nothing say anymore',
#  'breaking suicide blast u patrolled city syria white house say president trump briefed h',
#  'seen new poster got horrible feeling film going end goose cat turning',
#  'lmfao waiting someone react it and guy behind end finally realizes and cracking',
#  'espn host argues donald trump giving fast food clemson player racist team majority black really fa',
#  'okay called let u get it people freak announcer sound like refugee',
#  'registered memory prologue mv th calling nj kiling father nj and',
#  'it horrible feeling know thing gone wrong and nothing chance it',
#  'know weight matter and know it define anyone night look mirror and r',
#  'shift taken full speed rush ice beginning tagged another chance blue line',
#  'think nothing left still moon sunset favorite music paper write warm clothes',
#  'alright army listen since bighit did wanna responsible decided take matter hand',
#  'supposed religion peace know think someone lying',
#  'sharing story people impacted and urging gop let u vote end it h',
#  'people hating never bother nobody ever hate hate',
#  'girl committed suicide jumping front train video sex football team leaked someon',
#  'suicide hotlines always get shared recent news someone passing side note like always check',
#  'tracy whited died today hanging w bed sheet cell harris county jail held',
#  'actually tired bro like bottom heart tired',
#  'graduating semester and honestly sad see chapter life end college extremely dema',
#  'whatever it worth aware disabled issue five year disability tha',
#  'fact bro',
#  'really grateful wannable also want say worked hard member went hardship',
#  'jihadi tried kill president want everyone congress tie hezbollah and hamas investigated im',
#  'jin face cracking thing end blood seeat tear standing front mirror it happened',
#  'did know malaysia suicide helpline sam called befrienders and',
#  'morning routine includes minute sitting bed and thinking tired',
#  'harmony harmonizing bullshit involving note value ie hitting thing stick',
#  'kinda wanna kill kinda wanna prove beat depression really know gone win',
#  'chewing gum and lady asked left said yes and brought one udara agbalumo bag',
#  'suicide hotline number united kingdom united state canada ireland',
#  'hassan bhai think received big lifafa lately literally abusing ik and te',
#  'it make feel proud know almost year clean self harm and suicidal thought wow wow god',
#  'really hate good heart',
#  'sorry senator argument military presence anywhere islamist suicid',
#  'girl committed suicide jumping front train video sex football team leaked someon',
#  'funder deep state coup george soros declares end duly elected president well happy inform',
#  'people hating never bother nobody ever hate hate',
#  'gonna realize it business and coach going swear and keep happy it',
#  'could least bring finish dmc tried playing dmc alcohol new year eve aft',
#  'one beautiful and magical moment life came end and appreciate everyone came and shared',
#  'girl committed suicide jumping front train video sex football team leaked someon',
#  'today discussed government shutdown and need compromise end it npr feel free tune pm cst',
#  'already disconnected extent pushed and would',
#  'warning webtoon graphic and contains sensitive topic like suicide violence death and blood',
#  'hate feel like around someone come boring quiet person really',
#  'hate overthink bad mood',
#  'fucking dangerous dog slip get accident die want endanger life',
#  'warning sign depression ignore low self esteem guilt hopelessness fatigue in',
#  'story would end yes it went and friend',
#  'stop it please cant take it anymore',
#  'right used get lot like ten year back weather seems ch',
#  'want fucking die',
#  'isi suicide bombing syria kill record number u troop',
#  'thing going away and it end democracy unless it dealt',
#  'people hating never bother nobody ever hate hate',
#  'good use direct response marketing principle referral',
#  'yes let jennifer hudson stay trump tower family murdered provided se',
#  'warning webtoon graphic and contains sensitive topic like suicide violence death and blood',
#  'normalizing barr hearing shameful failure medium potus fired ag refusing end investigat',
#  'wanted learn local language live got great aboriginal fr',
#  'went airport security tsa agent turned tear eye and said chuck schumer dianne fe',
#  'never give addy always somewhere near',
#  'hello yes psa sensitive extremely triggered suicide death blood and violence graphic depic',
#  'settled life da la vega little wedding chapel u live would u it gotta u must',
#  'settled life da la vega little wedding chapel u live would u it gotta u must',
#  'grade school spelled human homan thought it short homo sapien and still',
#  'settled life da la vega little wedding chapel u live would u it gotta u must',
#  'hate life',
#  'tell playinnnnnnnnnn',
#  'mass suicide massacre',
#  'please watch end serious business',
#  'strong fight asked responsible rohit vemula suicide and najeeb ahmad joining',
#  'know it time get twitter and say goodnight maga family start replying people end',
#  'thats it suicide today',
#  'jin want change friend fate tryin fgure wht went wrong jin always recording friend coz alw',
#  'please watch end serious business',
#  'home horsford sunday look make it two win bounce another massive game u need',
#  'casuals give easily even want fight battle and run away like cucked p',
#  'hate overthink bad mood',
#  'series like hour horror film scariest part end realize horror still continue',
#  'movie epic love did broly it crazy it got point actually rooti',
#  'physically and emotionally exhausted always and tired it',
#  'problem tweeted told it mandatory prereg and l',
#  'jisoo jennie it jennie birthday and jisoo also next jennie pm en',
#  'cry better life affordable basic able feed child and send school th',
#  'want save want take stick away guy and break it right front deserve',
#  'long term habit healthy eating far effective short spree fasting and punishment diet',
#  'innovative since job passed tbh grown ignore and laugh along it',
#  'girl committed suicide jumping front train video sex football team leaked someon',
#  'always appears zionist u military industrial complex and neocon warmonger need coincid',
#  'remember year old student suffered triple fracture jaw following shot flash',
#  'jin want change friend fate tryin fgure wht went wrong jin always recording friend coz alw',
#  'cleopatra died disgrace committing suicide following defeat force mistress du jour marc antony',
#  'never going end it called war quote detective carver war end',
#  'people hating never bother nobody ever hate hate',
#  'did it lol',
#  'end man distinguished career slip tongue',
#  'know landlord caretaker mama mboga and course security guard gate',
#  'may mean and hammond co confirmed get brino tory mp backing',
#  'love much it may signify time loop end th april and jin escape it successfully goi',
#  'morning routine includes minute sitting bed and thinking tired',
#  'warning webtoon graphic and contains sensitive topic like suicide violence death and blood',
#  'pull card know many woman ruin peo',
#  'also surgery completely table it le likely know tear menisc',
#  'maybe flying car cure cancer resolution climate change',
#  'thing going away and it end democracy unless it dealt',
#  'literally hate people say nothing depressed literally know someone',
#  'warning webtoon graphic and contains sensitive topic like suicide violence death and blood',
#  'yeah bitch mom like wonder looked and want kill omg',
#  'see wrong billboard someone help did erase freckle two',
#  'year half crazy azz time travel theory confirmed first it seemed like ridiculous concept came',
#  'jin everytime traveling back april th save friend jungkook bro many time want see die',
#  'okay wow heavy trigger warning webcomic explicit suicide blood injury please take care',
#  'okay scum earth fuckin cover pic like crop tf bro nobody nee',
#  'kim jonghyun want die lee jonghyun',
#  'update jail could make bond',
#  'year half crazy azz time travel theory confirmed first it seemed like ridiculous concept came',
#  'morning routine includes minute sitting bed and thinking tired',
#  'please normalize already normal thing highly relabtle and get lot retweets tired n',
#  'feel swept carpet old petition resulted minor patching nothin',
#  'moment russia and assad took patrolling manbij trump go ahead get hit suicide bomber first',
#  'study find physician contemplate suicide',
#  'people hating never bother nobody ever hate hate',
#  'tired',
#  'jin face cracking thing end blood seeat tear standing front mirror it happened',
#  'girl committed suicide jumping front train video sex football team leaked someon',
#  'webtoon update every thursday and chapter it end april th day jin keep goin',
#  'decided want cremated die whenever surprise',
#  'dont think ppl realize say depressed exaggerating like twitter hoe shit',
#  'it end third quarter happened basketball',
#  'bts win oscar hyyh one way another imma take matter hand',
#  'girl committed suicide jumping front train video sex football team leaked someon',
#  'jin face cracking thing end blood seeat tear standing front mirror it happened',
#  'and life end nervous thisaaa',
#  'girl committed suicide jumping front train video sex football team leaked someon',
#  'it colourful dem born well suicide mission',
#  'ready fucking end it',
#  'mood',
#  'russia thanks want meet die putin',
#  'pain throat get worse voice cry and pleads father stop abuse',
#  'end thank much reading au it nice first experience and apologize mistake',
#  'happened proven world nothing lying hypocrite',
#  'also wanna make it clear fund keep open end day tech company',
#  'year old kid hi chaeyoung many thing worry life know young wild enj',
#  'it like double spacing essay need meet length requirement nothing actually add',
#  'one run cry without fearing judgment u really know much mean',
#  'yall hyyh making big comeback new era fcking know it and ive never ready entire fcki',
#  'year stage music and it coming close end month day',
#  'jin want change friend fate tryin fgure wht went wrong jin always recording friend coz alw',
#  'love much it may signify time loop end th april and jin escape it successfully goi',
#  'thing going away and it end democracy unless it dealt',
#  'yo imagine obama did ghetto shit like would never heard end it',
#  'saw tyler and yet did nothing',
#  'tear left cry stream global chart spotify it month since release',
#  'killing thinking much and deeply everything',
#  'episode and end april thursday date jin keep going back rep',
#  'one beautiful and magical moment life came end and appreciate everyone came and shared',
#  'hey sydney train air con service inhumane degree peak hou',
#  'it took famous corporate chieftain people notice coercive interrogation carlos ghosn h',
#  'toxic masculinity encourages unfeeling often violen',
#  'still confused people blaming shutdown trump two side standoff side ha',
#  'sometimes stare mirror and think pretty bitch hate',
#  'mcconnell want everything avoid shred accountability shutdown truth could',
#  'thing going away and it end democracy unless it dealt',
#  'thank sarah minimized forgotten ridiculed and invalidated point want kil',
#  'pre conference workshop navigating unknown tool caregiver highlight s',
#  'farmer commits suicide hanging deceased identified nagendrappa',
#  'suicidal lately point even typed goodbye letter last week looked e',
#  'democrat pissing like puppy thinking power guess nothing going get better',
#  'new clip mv brownie gave edible it also something else trapped and c',
#  'people want get everything usually end getting nothing life made big promise f',
#  'nothing and nobody discouraging except keep trying make better world and u l',
#  'hate slandered thinking cat gemini',
#  'democrat willing something far willing nothing obstruct',
#  'taekook au tae and gguk married and every year anniversary jeongguk sends bouquet flower along',
#  'everytime see tweet saying nct night night going end soon heart break inspirational',
#  'read please trump bolton and pompeo dismantling america security structure plank plank today announcem',
#  'let patient let kind make unselfish without blind may faith make mountain fall',
#  'sun set fantastic trip japan see perform brilliant solo show',
#  'calling commenting death migrant child say nothing angel mom wh',
#  'suicide hotline number united kingdom united state canada ireland',
#  'warning webtoon graphic and contains sensitive topic like suicide violence death and blood',
#  'normalizing barr hearing shameful failure medium potus fired ag refusing end investigat',
#  'jin want change friend fate tryin fgure wht went wrong jin always recording friend coz alw',
#  'one breathed sigh relief end tweet',
#  'excuse treat others poorly even rough childhood rise past cont',
#  'year old kid hi chaeyoung many thing worry life know young wild enj',
#  'society done absolutely nothing deserve someone talented sweet funny precious caring hardworking',
#  'singing bollywood song fill desert evening little and little end it mu',
#  'umm yelled cuz kill everybody gas station',
#  'girl committed suicide jumping front train video sex football team leaked someon',
#  'one thing hate something head it and it hard get',
#  'known comic version bts day anything happens kill everyone and',
#  'oh shame chinese worker survive suicide net',
#  'anyone saw jospeh kahn tweet national suicide hotline call need talk som',
#  'wow it really coming end well it amazing guess code good week',
#  'psychologist coming end talk compulsiveness con men and',
#  'certain point nothing lose brink expelled would allow',
#  'it maybe problem need get thru end week something repeat and often',
#  'never superficial u want master something get root it read it ask people go deeper',
#  'revealed abvp planted jnu controversy divert attention rohit vermula suicide',
#  'attacker dusit dead confirmed one died suicide bomber rest neu',
#  'dear defeated syria killed people suicide bomb attack syria incl',
#  'wonder would happen tragic accident wonder would visit hospital would claim',
#  'know tired yes jonah yes',
#  'it go and still taking responsibility chaotic humiliating shamble made brexit',
#  'else expect guy wasting time explaining fact end',
#  'tagging far credible trusted and professional journalism cloude',
#  'decided want cremated die whenever surprise',
#  'suicide bomber blew would anyone',
#  'still sustained federal inquiry hell happened puerto rico kill thousand ou',
#  'lmao hate bro',
#  'went airport security tsa agent turned tear eye and said chuck schumer dianne fe',
#  'it scared read webtoon bcs know would end cry day',
#  'something weird thought kid thought everyone different number teeth kept falling',
#  'hate working love spoiling',
#  'oms people aint shit man it aint even worth nice person anymore',
#  'plz dub actually almost end series could probably catch it english',
#  'apply eyelash glue lash line rather false eyelash dry second n also allows lash',
#  'end day proud hard work put day day always give it',
#  'madam time get high horse one tired stupid antic and b',
#  'thing going away and it end democracy unless it dealt',
#  'although attacked it worth it earlier day one woman heard sharing message jesus and de',
#  'toxic masculinity encourages unfeeling often violen',
#  'beatzcoin cut middle man and supporter',
#  'ultimate goal end like miserable people around settled life and perpetually bitter',
#  'read theory always cam gotta remember co bit memory fade away everytim',
#  'done must live promise otherwise shall calling removal across af',
#  'want fake relationship w end falling love w later u want',
#  'literally look stoopidddd laughing every time come across someone stupid illiterate spelling st',
#  'suicide saul bible england th century',
#  'reason shake thought life least bit suicidal ov',
#  'year old kid hi chaeyoung many thing worry life know young wild enj',
#  'ginger photocopy comic book mlj archie publication end date jan bid add watch',
#  'suicide hotline number united kingdom united state canada ireland',
#  'people suck people moment and use moment put order make moment feel imp',
#  'started realize needed friend checked and wanted nothing best without moti',
#  'suicide hotline number united kingdom united state canada ireland',
#  'whatever favorite organization trying achieve it highly rational prefer it focus advancing',
#  'opinion emery cannot afford make suicidal decision chelsea made v west ham',
#  'know god it end money longer problem and family',
#  'it inserted bcus medication side affect want take it anymore another reason',
#  'girl committed suicide jumping front train video sex football team leaked someon',
#  'yo imagine obama did ghetto shit like would never heard end it',
#  'girl committed suicide jumping front train video sex football team leaked someon',
#  'it year since heard voice year since able hug go workout',
#  'lot call extend problem euroelections may cant stand candidate meps still li',
#  'yo imagine obama did ghetto shit like would never heard end it',
#  'it suck loving someone giving giving fuck it hurt like hell dreading ove',
#  'yup',
#  'giving away so sticker collection etsy bio enter givea',
#  'morning routine includes minute sitting bed and thinking tired',
#  'it obvious dickwad watch try comment mccoy fell depth chart quick nb star',
#  'believe news follow technical analyst dwell price swing best chance',
#  'give',
#  'beta girl chase steve wanted get cold posturing',
#  'year old kid hi chaeyoung many thing worry life know young wild enj',
#  'man committed suicide apartment building year ago found today',
#  'fucking dangerous dog slip get accident die want endanger life',
#  'old icu rn good thing age type illness ca',
#  'maybe flying car cure cancer resolution climate change',
#  'it extremely upsetting sc hillary lost and nothing',
#  'man ot funnest hockey seen pity it end shootout',
#  'jihadi tried kill president want everyone congress tie hezbollah and hamas investigated im',
#  'le person panic attack intrusive thought suicidal thought anxiety',
#  'actually tired bro like bottom heart tired',
#  'thank retweeted followed and read article today go life wondering it',
#  'thing going away and it end democracy unless it dealt',
#  'dawn break become uneasy and end cry tear whispered it okay also',
#  'started watching vampire diary bc kept seeing tweeting it season want it e',
#  'strong fight asked responsible rohit vemula suicide and najeeb ahmad joining',
#  'always speculates awaits future accomplishes nothing whatsoever understood true',
#  'yall hyyh making big comeback new era fcking know it and ive never ready entire fcki',
#  'moment russia and assad took patrolling manbij trump go ahead get hit suicide bomber first',
#  'reply azkal fan may happy goalie falkesgaard nothing praise f',
#  'logan paul joking gay one month countless lgbt around world killed committing suicide f',
#  'tear think it happy ending and jin learn love and ac',
#  'thank',
#  'altruism people money rapidly metastasizes pathological suicidal',
#  'jin face cracking thing end blood seeat tear standing front mirror it happened',
#  'like rudy giuliani arguing presidential candidate nothing',
#  'people dont remind stay alive want end it dont deserve people watch cr',
#  'hello jeremy did see wrap missing it nothing environmenta',
#  'honestly obsession making attendance important part grade stupid cuz end class ei',
#  'jin face cracking thing end blood seeat tear standing front mirror it happened',
#  'stop living people lost take l',
#  'one would thought sport team turned white house visit trump would se',
#  'people suck people moment and use moment put order make moment feel imp',
#  'song know it inspires give want and keep chasing dream matter come',
#  'view poured four week quintupled expectation and pursued avenue it',
#  'claim kukbhushan jhadav indian spy pray death leader like amit',
#  'hit blue and run exciting problem literally nothing able kill ever',
#  'altruism people money rapidly metastasizes pathological suicidal',
#  'actually tired bro like bottom heart tired',
#  'tough loss game like teach team better next time good friend told',
#  'guy think chance get happy ending end hospital',
#  'girl committed suicide jumping front train video sex football team leaked someon',
#  'need get syria',
#  'bombing deadliest attack american controlled city liberated',
#  'sharing story people impacted and urging gop let u vote end it h',
#  'surveillance video capture moment suicide bomber detonated vest manbij syria american among killed',
#  'nothing inside compels latch onto guy opportunity may miss opportunit',
#  'girl committed suicide jumping front train video sex football team leaked someon',
#  'suicide bombing syria kill u troop',
#  'actually tired bro like bottom heart tired',
#  'year old kid hi chaeyoung many thing worry life know young wild enj',
#  'nope work twitter bot real life year old tired fake as',
#  'pelosi try delay trump address democrat want trump speak border securit',
#  'might take question and answer totally different question one asked and fol',
#  'making progress excited go check it and give it follow http',
#  'jin want change friend fate tryin fgure wht went wrong jin always recording friend coz alw',
#  'ok confirmed k sub end debate sub twitch',
#  'people hating never bother nobody ever hate hate',
#  'one breathed sigh relief end tweet',
#  'remember year old student suffered triple fracture jaw following shot flash',
#  'idk saw it getting one chapter every week april curious',
#  'american people want shutdown end it putin want keep de',
#  'said defeated isi syria liar u troop assassinated isi syrian suicide b',
#  'world desperately need large and massive suv choke and kill little left nature and cours',
#  'must zambia always thing nature and forth whereby joke befalls belove',
#  'everytime jin go back time memory becomes clouded power come without price allowed go back',
#  'people hating never bother nobody ever hate hate',
#  'day want give today one day',
#  'kidding never missed appointment procedure doctor',
#  'member died bc suicide accident met dna lyric dna vein tell',
#  'morning routine includes minute sitting bed and thinking tired',
#  'euphoria like metaphor suicide die moment euphoria ease pain de',
#  'webtoon update every thursday and chapter it end april th day jin keep goin',
#  'member died bc suicide accident met dna lyric dna vein tell',
#  'think thing lost it nothing else would console and try lose it',
#  'actually tired bro like bottom heart tired',
#  'mike penny gave speech today saying vanquished isi syria and never even mentioned people including four amer',
#  'feel bigger comeback cannot believe year finally getting answer wai',
#  'find time and vote confirm barr although unsuitable yet end gove',
#  'year old home know graduation yes parent still pay phone',
#  'wrong',
#  'islam and suicide',
#  'deleting last tweet think phrased it well end thread sorry miss',
#  'le person panic attack intrusive thought suicidal thought anxiety',
#  'cctv footage stupid suicide bomber blew alone god confused th',
#  'used silent fan take it anymore wanna shout world much happy and',
#  'yes would mean coalition government it would also see end ideological p',
#  'may never get point feel suicide option',
#  'friend made suicide and mental health awareness video thought',
#  'it and nothing trump end it going change fact',
#  'apparently car scene highlight reel part jin eventually purposely run jungkook end',
#  'last night donal delay mocked friend mother suicide deleted everything posted ra',
#  'noooo pls',
#  'remember hitachi scrapping bn nuclear power station like jaguar land rover etc cutting thousand job',
#  'jamshoro suicide live news pakistan via',
#  'german newspaper rheinische post argues uk divided it would impossible accommodate uk eu member',
#  'suicide right answer',
#  'die tonight want everybody keep energy yesterday stand',
#  'rashida truth diary it rather easy going airport looked eye worker deserv',
#  'went airport security tsa agent turned tear eye and said chuck schumer dianne fe',
#  'people country support self id thank making it clear and welcome',
#  'girl committed suicide jumping front train video sex football team leaked someon',
#  'jeremy corbyn collaborates tory custom union and labour end voting deal take away',
#  'euphoria like metaphor suicide die moment euphoria ease pain de',
#  'and irony shes fucking doctor literallt cant holy shit take anymore it two month and ten',
#  'girl committed suicide jumping front train video sex football team leaked someon',
#  'find appalling prison nurse',
#  'dude nerve say defeated isi syria hour troop killed isi suicide bomb',
#  'knew something iffy listening euphoria made happy since did anything hyyh rela',
#  'jin want change friend fate tryin fgure wht went wrong jin always recording friend coz alw',
#  'girl committed suicide jumping front train video sex football team leaked someon',
#  'gay straight pan asexual tired',
#  'member died bc suicide accident met dna lyric dna vein tell',
#  'success lonely path and dare stick it end willing walk path success h',
#  'yo imagine obama did ghetto shit like would never heard end it',
#  'uh webtoon need heavy warning suicide please careful reading and',
#  'member died bc suicide accident met dna lyric dna vein tell',
#  'agreed making ethical demand k invested imperative',
#  'unless tried commit suicide go hunger strike detention centre forgotten unnoticed detention',
#  'look adorable animated baby want see die alright',
#  'girl committed suicide jumping front train video sex football team leaked someon',
#  'suicide hotline number united kingdom united state canada ireland',
#  'fuck armchair everytime listen euphoria ill get sad and end cry and thinking entire bts univers',
#  'radicalized year old arrested fbi sting planning white house suicide attack using ied and anti tank r',
#  'member died bc suicide accident met dna lyric dna vein tell',
#  'bitch put close friend list it mean trust enough keep goddamn mouth shut and and mind ow',
#  'matter many time seungri asks respect yhs thing fan know',
#  'blue mage job came final fantasy xiv job spontaneously self destruct anywhere and anytim',
#  'physical appearance year old woman chronic health conditio',
#  'sound great it really people saying kept money raised cyntoia brown never even ra',
#  'used silent fan take it anymore wanna shout world much happy and',
#  'considering urine sterile it leaf body safe say isnt bad people believe',
#  'friend made suicide and mental health awareness video thought',
#  'feel today honestly want die',
#  'did say university generally left leaning extreme left',
#  'literally none true first sentence',
#  'deal course mean suicide brexit it would mean end car manufacturing and aerospace ind',
#  'ian blackford bothered mention cfp speech lasting minute right',
#  '',
#  'trump lied surprising turn event said nobody brain cell',
#  'okay wow heavy trigger warning webcomic explicit suicide blood injury please take care',
#  'lol one boyz mad it onto video damn funny end and',
#  'ignore massive male suicide rate',
#  'like forgiving person earth also stupidest giving people opportunity break damn hear',
#  'meth son get come home day luxury al',
#  'trump claimed nothing russia medium proved did claimed defeated isi isi p',
#  'remember isi victim muslim medium fixates western victim today suicide bombing syria ill',
#  'agree chris go football groun',
#  'it pay it tied net worth rich enough',
#  'baba mad asked change light bulb room instead it',
#  'think feel nostalgic it and get confused',
#  'also make sense',
#  'yunho ig yunho thailand trip fun end and local people and everyone e',
#  'greater manchester standing together hate crime sign pledge',
#  'chicago police sgt lori rice found dead apparent suicide',
#  'murderer straight nothing funny say offended',
#  'blackmail partner suicide self harm literally anything damaging break know yo',
#  'leave demi lovato alone damn joking addiction suicide funny it never never',
#  'sick and tired administration lying evil inflicted child sepa',
#  'want know it make certain people see and think love kill',
#  'fucking app shit brain go learn work first time',
#  'girl unfortunately cookie crumbles keep crown queen even amazing king adjust',
#  'powerful post thank sharing',
#  'want donate verify it going cause think it chi h',
#  'chicago police sgt lori rice found dead apparent suicide',
#  'it really sad african country economically enslaved west and seemingly nothing sort',
#  'want know it make certain people see and think love kill',
#  'go it go empathetic humanity',
#  'whenever wherever cant remember forget underneath tour clothes empire wo',
#  'tweet tired and exhausted pero hindi naman talaga it right word cannot find',
#  'kill ever lost job and go work bullshit corporate company gare l',
#  'ed courtship west short lived rejection rejoin commonwealth following last week event',
#  'south african it clear game play africa r always',
#  'overthinking able sleep actually really tired',
#  'it come thing transgender come expense girl and woman america famously outspoken',
#  'tired waiting world become good and beautiful and kind langston hughes',
#  'dont pet',
#  'democrat claim pro choice true want u choosing healthcare want take ch',
#  'chose scared make look weak informed and concerned vulnerable next generatio',
#  'comforter got twisted inside duvet cover obviously ready end it',
#  'yesterday made it year since nearly died hand abusive ex it something wish anyon',
#  'it okay did need heart anyway absolutely gorgeous soft and hot and sexy together',
#  'sick and tired people like lying policy it policy talking created b',
#  'whatever flaw might nothing compared dangerous pollution it pre',
#  'cap god',
#  'wanna know bts skincare routine bc one day fucker couple lil pimple and next day',
#  'im really point stan phase matter gon happiness fuck yg wasting journ',
#  'thank helping reach follower literally done it without thank much agai',
#  'frightening amount boy getting jumped carmondean dean area past week horrific',
#  'it ok people like still human and emotion still struggle severe depression',
#  'u want relief disease u follow real way worship given',
#  'watch youtube queen baby uploading',
#  'well well it unique end year and beginning year u tech demonstration and ba',
#  'retd dgp wb mazumdar paid lakh month saradha group vp tmc arrested sep dgp',
#  'son suicide watch please keep thought and send u strength',
#  'sometimes think want disappear really want found and understood',
#  'spoiler alert going it banning gay people',
#  'every single day think going police pointless believed thread make thin',
#  'writing say super bowl boring lame non suspenseful never ending drool puddle e',
#  'retd dgp wb mazumdar paid lakh month saradha group vp tmc arrested sep dgp',
#  'long flight john grisham book left behind it unputdownable reached th',
#  'scared even ready die country and save constitution mamata banerjee',
#  'want die',
#  'want kill',
#  'hello lovely sun looking pal rabbit every day and general bc nothing else week it',
#  'democrat claim pro choice true want u choosing healthcare want take ch',
#  'bro psycho ugly ducking mutt im crazy hate lmaoooooooooo',
#  'father son end it it and god and god and rest never ev',
#  'pony nothing better shit and everything good it going it man stfu toxic fanboys',
#  'fuck life touch ur foot gonna kill end daddy',
#  'kind awful and probably',
#  'dont want hear watch way baby born alive killed left die',
#  'retd dgp wb mazumdar paid lakh month saradha group vp tmc arrested sep dgp',
#  'retd dgp wb mazumdar paid lakh month saradha group vp tmc arrested sep dgp',
#  'it shameful note igbo friend plan vote atiku want die and hi',
#  'sonar make beaked whale suicidal and know',
#  'it shameful note igbo friend plan vote atiku want die and hi',
#  'know need see tear eventually end joy replace pain used keep nig',
#  'and sick and tired and democrat treating law breaker thery god',
#  'like ppl really put ad reason literally cant anymore done and new orleans fault shitty luck',
#  'booty content end weekend full set available physical photo book',
#  'suicide never answer pet miss',
#  'whatever want it cannot change past future atte',
#  'greater manchester standing together hate crime sign pledge',
#  'tired want go bed cannot skip routine it exfoliate mask night',
#  'journalist deliver news happen need push agenda narrative p',
#  'sick and tired administration lying evil inflicted child sepa',
#  'imagine example germany uk denmark producing kind public diplomacy video one almost get sec',
#  'leave demi lovato alone damn joking addiction suicide funny it never never',
#  'life told rise better person family and people told would and',
#  'want die',
#  'much mere dry mouthed fatigue storyline nfl failing address',
#  'reminded people charged russia probe trump responded excuse ok ready ok ready',
#  'following allegation and',
#  'dear mr may it pizza it brexit brexit national suicide and please stop referring deal really',
#  'dont like ozil carzola one service one create chance one',
#  'love hurt',
#  'really hate lately',
#  'always think making pirogi fun experience always end kitchen hour questioning life',
#  'bbc britain side expect money it get eu make it brussels propaganda machine',
#  'people venezuela remember well it like u colony make mistake would fight u intervention',
#  'another family suffering pain tax scam also point another interesting factor affe',
#  'suicide hotline addiction hotline eating disorder hotline se',
#  'suicide never answer pet miss',
#  'fifteenth amendment granting black men right vote ratified day yet saw georgi',
#  'suicide never answer pet miss',
#  'sometimes it form love talk somebody nothing common and still fascinated thei',
#  'hate goodnight everyone',
#  'mean must end still ripping public even k subm',
#  'blackmail partner suicide self harm literally anything damaging break know yo',
#  'added spotify official playlist pop rising it huge playlist it important stream th',
#  'koi deal mang nahi raha inn ko dainay ki kitne jaldi hy',
#  'suicide never answer pet miss',
#  'thief trying take land wall approved',
#  'suicide never answer pet miss',
#  'ha did it birthday cul end nowhere france and brought puddi',
#  'porn first thing went sesta fosta reason social medium going sh',
#  'hear speak see coman kill',
#  'know need see tear eventually end joy replace pain used keep nig',
#  'fifteenth amendment granting black men right vote ratified day yet saw georgi',
#  'time everyone call lie expect medium ab',
#  'community tweet',
#  'retd dgp wb mazumdar paid lakh month saradha group vp tmc arrested sep dgp',
#  'barely inverted comma around totally false imply it',
#  'semester break best nothing except focus also worst hate',
#  'sick and tired administration lying evil inflicted child sepa',
#  'lady recently lost son contact time morning suicidal universal credit giving qu',
#  'team gc gon congrats kid guy made it hun congrats beloved dongsaeng guy deserved it yed',
#  'yes it true officially longer disappointing must celebrate vision decade ago g',
#  'did write get everybody hate goal and purpose life dream book bcs it happening',
#  'it better come even though really really want come malaysia local freak',
#  'hogwash benefit britain brit immigrant eu country and beyond contribu',
#  'experience intense suicidal ideation period',
#  'guendouzi seems take time ball and try draw foul it fair worry',
#  'brexiters leading economist saying run car industry remember nissan',
#  'illegal immigrant pay sle tax',
#  'ceo saradha medium tmc mp kunal ghosh salary lakh month director saradha resort',
#  'ceo saradha medium tmc mp kunal ghosh salary lakh month director saradha resort',
#  'fbi agent exposed hillary clinton cover found dead another seasoned professional suicide could put nice den',
#  'retd dgp wb mazumdar paid lakh month saradha group vp tmc arrested sep dgp',
#  'lot people saying month and may constantly said way stop deal vote',
#  'want know it make certain people see and think love kill',
#  'elected president asuu strike end first day office atiku via',
#  'korean lesson today and yesterday trying make folder and instead normal note',
#  'it still official',
#  'set back blessing disguise prayer hopeless never forsaken see reason',
#  'it public issue telling commentator suck dick it necessa',
#  'ceo saradha medium tmc mp kunal ghosh salary lakh month director saradha resort',
#  'leave demi lovato alone damn joking addiction suicide funny it never never',
#  'hate new',
#  'organisation show reality life homeless friend live nothing sugar coated false advertisement',
#  'end day man',
#  'like real wrong crush enemy well really enemy actually',
#  'rt crush miss someone want die hate horrible family identifies lgbtq hav',
#  'dont want hear watch way baby born alive killed left die',
#  'pretty girl short hair dangerous bc make think it good idea cut hair end lookin',
#  'medical crisis manus getting worse day day mental illness seen police problem manus hea',
#  'agree end follow it easier opt third party main two awful',
#  'laugh exactly minding business yall attacking nothing',
#  'worker and consumer deal potential cause problem million uk particularly it happens',
#  'payment received lic end always send email confirmation please note it may',
#  'wrote know react single page deep dive and beginner friendly post bel',
#  'cross government suicide prevention plan ignores dwp via',
#  'knowledge help others help dalits',
#  'it though always seem end going circle bring back smile',
#  'give and oh tired oh god cannot it reason g',
#  'jesus common name back and roman liked crucify it would surprise guy called',
#  'pose end ugh serving look',
#  'michael would feel suicide bomber attack policeplaza ny police officer die fighting terrorist',
#  'giveaway rule retweet tweet follow choose one item picture worldwide end',
#  'fifteenth amendment granting black men right vote ratified day yet saw georgi',
#  'one find funny',
#  'absolute poverty v relative poverty left per',
#  'want disappear',
#  'shashi tharoor charged section and ab',
#  'allergic accountability even think it okay bring call out call in',
#  'it crazy whole month people watched people start relationship end relationship st',
#  'brexiters leading economist saying run car industry remember nissan',
#  'nothing tweet true and tired people live virginia retconning two year old state prima',
#  'afraid anymore make sure need forget it walk door and leave',
#  'umjita it actually safer it indoors really uncomfortable unless person u explicitly agreed',
#  'right did faith female lead superhero movie also see movie profit',
#  'it money making business got end',
#  'cbd melbourne woman problem nothing see west brisbane branch young liberal national deci',
#  'yeah likely think herrea put ball line stood and looked awa',
#  'another one',
#  'showdown coming told and it time end help',
#  'mean dnt want give yet',
#  'meant short post happiest news excited past month turn',
#  'leave demi lovato alone damn joking addiction suicide funny it never never',
#  'and almighty god kabir kill cancer u really want get rid cancer lord kabir',
#  'people always show care late finally given and care anymore',
#  'people treat god like pain pill use needed treat like water cant live without',
#  'end it good day',
#  'hate branded spoilt parent afford give best life possibly want',
#  'it easy bully hate people era want remembered gone w',
#  'end thread hey much possible always answer anything one thing ch',
#  'retd dgp wb mazumdar paid lakh month saradha group vp tmc arrested sep dgp',
#  'and yet complain going schl normal human body',
#  'it easy assume kaiba learned nothing yugi penalty game end death marked',
#  'ceo saradha medium tmc mp kunal ghosh salary lakh month director saradha resort',
#  'economy going south bank ripping u flood fire west brisbane branch young liberal n',
#  'ceo saradha medium tmc mp kunal ghosh salary lakh month director saradha resort',
#  'happy little people nothing still manage smile',
#  'deserve shit thru it made better and stronger person complaining happy',
#  'yep bring end it much take',
#  'it trap get viewer hope realize did mad awful did want sicko mode',
#  'wondering it gonna end barry halen found bih',
#  'nothing say',
#  'brexiters leading economist saying run car industry remember nissan',
#  'pizza kill',
#  'sick and tired administration lying evil inflicted child sepa',
#  'happy birthday beautiful friend hope filled nothing love and happ',
#  'tired',
#  'ceo saradha medium tmc mp kunal ghosh salary lakh month director saradha resort',
#  'it person wanna share good bad news end day baka siya na',
#  'it perfect it get end power allowing',
#  'nothing say',
#  'guy one wearing maga hat march life kid diocese wea',
#  'retd dgp wb mazumdar paid lakh month saradha group vp tmc arrested sep dgp',
#  'last shutdown caused immeasurable pain american worker contractor famili',
#  'ceo saradha medium tmc mp kunal ghosh salary lakh month director saradha resort',
#  'fifteenth amendment granting black men right vote ratified day yet saw georgi',
#  'absolute poverty v relative poverty left per',
#  'get it everyone shocked pic democrat always raci',
#  'paid guy tweet lie abouttaxify uber anaaa it funny use service yet lying may',
#  'suicide never answer pet miss',
#  'important story great',
#  'going go live life going go enjoy life nothing left hide kind free person fr',
#  'big relief shashi tharoor case culpaable homicide abetment suicide trial start',
#  'thanks mute option live life peacefully tl either filled sc fan',
#  'hello middlesbrough front end new meet taking place middlesbrough it place developer design',
#  'journey never ending always gonna growth improvement adversity gotta take it',
#  'cwn pope francis appeal end humanitarian crisis yemen',
#  'know it feel like someone loved cared would give shirt back back door like nothing',
#  'breaking morrison lock child mita detention camp child frm nauru little girl biloela baby',
#  'know it feel like someone loved cared would give shirt back back door like nothing',
#  'cannot let pardon dangling become normalized defending well stone cooperating stone sayin',
#  'hate anyone anything anymore stopped caring lot thing thing bothered mind',
#  'ceo saradha medium tmc mp kunal ghosh salary lakh month director saradha resort',
#  'gadkari sir marathi bt feel marathi like stupid uddhav thakre al',
#  'double ko correct way it end',
#  'inshallah die state worship',
#  'leave arsenal alone hate dude whole life',
#  'retd dgp wb mazumdar paid lakh month saradha group vp tmc arrested sep dgp',
#  'panini select signature silver prizm rickey jackson auto card end date monday feb',
#  'wtf k',
#  'ceo saradha medium tmc mp kunal ghosh salary lakh month director saradha resort',
#  'adding lmao end sentence make it seem like sad fuck',
#  'lifeless body year old zanele zwane nhlazatje mpumalanga went missing dec found buried',
#  'told friend feeling suicidal due new birth control w k',
#  'narok county first lady sarah tunai need everybody it one person mandate end fgm save one perso',
#  'ceo saradha medium tmc mp kunal ghosh salary lakh month director saradha resort',
#  'it beginning end national butterfly center wall go',
#  'mildly peeved got locked call suicide yet many n found tweet',
#  'life fucking meaningless',
#  'hurt want go find save get safety cannot passed',
# ...
#  'wonder new eu japan trade deal agreed end anything it',
#  'delhi court sent sunanda pushkar case congress leader session court proceedi',
#  'stop playing around playing people playing bullshit partisan politics it obvious wanted sell water govt ha',
#  'hate new school hate life iwanna die',
#  'cheerdance research dance drama pop book report educational book etc suicide be suicide angnaaaa',
#  'it shameful note yoruba friend plan vote buhari want die and',
#  'blackmail partner suicide self harm literally anything damaging break know yo',
#  'ceo saradha medium tmc mp kunal ghosh salary lakh month director saradha resort',
#  'shii and everyone emotion inside like want accept it and rebel end everyo',
#  'wealthy celebrity vote party aiming end homelessness social inequality and child poverty wh',
#  'sterling fall pm may move end brexit impasse graphic trade weighted sterling sinc',
#  'trump call keeping troop iraq watch iran possibly upending isi fight keep base iraq',
#  'it person wanna share good bad news end day baka siya na',
#  'ceo saradha medium tmc mp kunal ghosh salary lakh month director saradha resort',
#  'rome ruin lion free coliseum poisoned place anti venom begin',
#  'hahaha requirement secret ending report three character youtube it',
#  'credibility going commit suicide people like utter it',
#  'ed courtship west short lived rejection rejoin commonwealth following last week event',
#  'free suicide prevention training learn save life book please visit',
#  'depression and suicide rate rose alarmingly debt crisis health expert and recent study say greece cut',
#  'ceo saradha medium tmc mp kunal ghosh salary lakh month director saradha resort',
#  'hate much',
#  'it amusing watch everyone scramble rich and live recognition and fame next',
#  'mother heart broken child died tragic event and really make',
#  'social anxiety nothing weak shy unconfident false it could mean',
#  'girlfriend said want knelt and beg insists wanted kill drank coke',
#  'going go live life going go enjoy life nothing left hide kind free person fr',
#  'hi would like buy magic bullet bed bath and beyond employee ooh making smoothy huh clenching',
#  'ceo saradha medium tmc mp kunal ghosh salary lakh month director saradha resort',
#  'team gc gon congrats kid guy made it hun congrats beloved dongsaeng guy deserved it yed',
#  'ceo saradha medium tmc mp kunal ghosh salary lakh month director saradha resort',
#  'wait laughed meme related deportation and making joke suicidal attempt',
#  'ceo saradha medium tmc mp kunal ghosh salary lakh month director saradha resort',
#  'seeing many reaction story somewhere snark and skepticism make sense given trump admi',
#  'leave demi lovato alone damn joking addiction suicide funny it never never',
#  'and yet complain going schl normal human body',
#  'shashi tharoor charged section and ab',
#  'swear want kick men p fucking die one time',
#  'people treat god like pain pill use needed treat like water cant live without',
#  'suicide never answer pet miss',
#  'take time see man failure it time join million n',
#  'accurate course almost never pointed brexiters really believe tech solve',
#  'it okay hate hate',
#  'corporate interest preempted public interest long people cannot even tell difference anymore',
#  'demanding america made great specific metric actually looking thing exactly',
#  'accurate course almost never pointed brexiters really believe tech solve',
#  'absolutely agree hear wonderful thing aap ground ordinary people nothing appears',
#  'tired one clean house live alone still',
#  'come troublu',
#  'deep conversation trash want talk universe happens die rather talk r',
#  'tired ignored',
#  'hi would like buy magic bullet bed bath and beyond employee ooh making smoothy huh clenching',
#  'please note february promotion upcoming monthly promotion start th month end nd',
#  'pop quiz day peeping lab keep calm and many time it say bt wall',
#  'n e way tired gn',
#  'relate know donald k furloughed federal employee bill going past due rememb',
#  'man never arrested despite wife dead case husband law spent',
#  'hypernormalisation process taken decade implement reality and falsehood indistinguishable',
#  'shashi tharoor charged section and ab',
#  'demi literally laughing shit yalllll tweeting yall mad joking drug addiction and',
#  'may think nothing god use voice may much education god still use',
#  'suicide never answer pet miss',
#  'nayeon stans spoiled and cant even live full day without mean atleast post photo hand foot',
#  'manager sound immature childish gone end revenge porn lawsuit cause want act like',
#  'tired',
#  'suicide never answer pet miss',
#  'hi decided hold another raffle time it couple art rule must following enter',
#  'desperate hope might stumble upon discarded ciga',
#  'want know it make certain people see and think love kill',
#  'hi would like buy magic bullet bed bath and beyond employee ooh making smoothy huh clenching',
#  'manager sound immature childish gone end revenge porn lawsuit cause want act like',
#  'really hate ask think best option made gofundme top surgery',
#  'hi would like buy magic bullet bed bath and beyond employee ooh making smoothy huh clenching',
#  'accurate course almost never pointed brexiters really believe tech solve',
#  'it year since tried end life stigma saw hospital bpd broke heart made vow',
#  'shot base skull release information would brought thatcher government',
#  'ceo saradha medium tmc mp kunal ghosh salary lakh month director saradha resort',
#  'people preach importance self care and mental health individual joking',
#  'suicide hotline addiction hotline eating disorder hotline se',
#  'it hour since end and developer already made way brussels',
#  'dear whatever difference south african political party race gender',
#  'dont know wtf wrong cant make video im sitting and dont even know say cant play',
#  'it person wanna share good bad news end day baka siya na',
#  'andrew mather st battalion royal irish regiment andrew crucial helping',
#  'slowly killing',
#  'innes hate right join queue',
#  'shii and everyone emotion inside like want accept it and rebel end everyo',
#  'creative young brain cell committed mass suicide and',
#  'one ten young people experience mental health issue one time aged suicide second com',
#  'right deal discussion obscure fact brexit whic',
#  'want change something it change requires action mere talk get nowhere people lofty id',
#  'often hate putting people first hate could easily feel bad everything',
#  'today mark start live laid',
#  'would ok it got tf office man like wont play rule long sc',
#  'bruh folk gone fw want fuck it matter long loyal folk dont gaf abt stop beg',
#  'like it comfort zone sometimes like used able kind disappear like uh',
#  'sure running clock pm plan parliament one final chance grow pair and lab',
#  'maybe seven sea rhye seeing fuckton rye bread tired almost havent slept yet plwaeqse ignroe',
#  'nothing say',
#  'understand men god alfa meant available time case people need spir',
#  'thank ballin season hope see back next season',
#  'imagine example germany uk denmark producing kind public diplomacy video one almost get sec',
#  'petrified jpc investigation done wrong modi ji rahul gandhi w',
#  'wrote know react single page deep dive and beginner friendly post bel',
#  'four year old mental breakdown asked old and said burst tear',
#  'fact silent mean nothing say',
#  'savage get arrested ice and it fuck ice right regular people get violated',
#  'attention end post u could see finger heart button similar one vapp click butt',
#  'love jayz did u say time na better jayz takeover v ether know lot pe',
#  'yes it true officially longer disappointing must celebrate vision decade ago g',
#  'come conclusion die alone cuz want kid man gunna wanna stay and',
#  'hahahahaha twitter wild',
#  'please let together end',
#  'facing monday blue worry thank god it monday networking opportunity every end it de',
#  'it nomayini get anything make u financially strong spiritually strong physically st',
#  'q report and patriot opinion rbg think probably dead obviously dems want president rep',
#  'parent spoiled rotten growing and also taught work nothing handed',
#  'man hate waking go back sleep',
#  'men constantly shout woman gold digger idea deal woman want nothing wi',
#  'slayer shazam detected feat k shazam let u go k end week',
#  'brexiters leading economist saying run car industry remember nissan',
#  'learned nothing iraq libya syria vietnam amazing horrible coverage it almost like',
#  'want die',
#  'pretty girl short hair dangerous bc make think it good idea cut hair end lookin',
#  'guess really sign it come end',
#  'want end life bts and lyric corner room looking',
#  'good example incoherent policy making one part european commission pushing meet climate and and e',
#  'hello middlesbrough front end new meet taking place middlesbrough it place developer design',
#  'yep would go along arrived and it much confident and optim',
#  'better way end dope as sum linked homie and dominated',
#  'everyone said get back pay psa nearly half national park service p',
#  'daily basis convince others nothing wrong it could wonwoo problem',
#  'may think nothing god use voice may much education god still use',
#  'name donna ill patterson aware today deposit day rd sunday',
#  'realize men also started it right',
#  'cry help people reaching get support ind help it dark and scary place',
#  'end day aspire thing like equal pay equal voice need show spine convic',
#  'difference dressing person different race and trying pas person di',
#  'whether it rough season it incredibly important continue staying positive and enthusiastic time',
#  'wrong administration senator evil lie u way',
#  'say american capitalism failed nigeria follow chinese model state owned enterprise wa',
#  'nothing better and know play game cheat',
#  'beyond tired though lack sleep got eye burning',
#  'disgusted government fact simply kiss dictator as make wanna f',
#  'end want calm longer appreciate extravagance and grand noise world sickening compe',
#  'want set one thing straight time important someone kid responsibility and thi',
#  'actual representation hate giving people phone wanna see photo even dick',
#  'eu data protection authority received complaint three common concern area nothin',
#  'pose end ugh serving look',
#  'people believe world end cause it ending gradually',
#  'take home message junior bank employee embezzle money bank yo',
#  'morgan push quick trot sloping road guessin need th',
#  'better fight something live nothing general patton',
#  'wish people aware matured human being capable understanding and accepting rejection',
#  'want state react way state did',
#  'feel nearing end nightmare it tough beginning ready take challen',
#  'living being want need work never grow old n',
#  'alright see saw repetitive seesaw trying put end it right tired seesaw',
#  'start squash across pond found',
#  'want know it make certain people see and think love kill',
#  'happy see lithuanian government taking step ban believe shou',
#  'sick and tired people like lying policy it policy talking created b',
#  'girl boy bestfriends heart please pahalagahan niyo sila always take care give th',
#  'want know it make certain people see and think love kill',
#  'pretty girl short hair dangerous bc make think it good idea cut hair end lookin',
#  'tired chasing',
#  'accurate course almost never pointed brexiters really believe tech solve',
#  'one want share first sandal number missed it end last week',
#  'barkha ji retweet tweet congress started investigation mamata banerjee',
#  'okay ducky ducky ducky write everything saying got it yes okay important going tell',
#  'men constantly shout woman gold digger idea deal woman want nothing wi',
#  'guitar it appeared mostly prop sure actually played',
#  'want know it make certain people see and think love kill',
#  'take tweet serious ur personal issue bmt',
#  'tired one clean house live alone still',
#  'idc taste music see live nothing love fella h',
#  'thank plan international great work end practice fgm af',
#  'gotten voice ilesha baruba accolade wait it shocked',
#  'im really point stan phase matter gon happiness fuck yg wasting journ',
#  'totally agree nothing wrong social housing many people low wage cannot afford save mortg',
#  'great defensive effort side finally pulled it and got end zone',
#  'fifteenth amendment granting black men right vote ratified day yet saw georgi',
#  'hv said it say it it never late go back islamiyyah instead wasting ur time forming',
#  'tired one clean house live alone still',
#  'continuation mercy pray believing one day god change cause',
#  'also end day love letting go something someone cant happy',
#  'rule islamic country would internal fighting left',
#  'it normal cat sound like know nothing cat yet im dying one',
#  'hate fukkin nightmare life want it end right fukkin',
#  'yes it happened penalty rate and govt single parent pension child',
#  'take everything personally it something desperately trying shake smallest thing send back',
#  'pop quiz day peeping lab keep calm and many time it say bt wall',
#  'osinbajo massob reveals allegedly want kill vice president',
#  'cling tightly gun die b',
#  'tired and want die already',
#  'almost given hope want cry damage done nightmare end',
#  'equality act sexual orientation and gender identity discrimination black people descendant',
#  'know say anything it yesterday going say it reaction turning point thing',
#  'accurate course almost never pointed brexiters really believe tech solve',
#  'imagine personality revolve much around anime enjoy it anymore since it becoming main',
#  'realize men also started it right',
#  'get tired and w ppl leave alone everyone',
#  'did implied',
#  'struggle icon fought hard u black people given opportunity vote people want',
#  'modern man cast spell truly loving woman nothing except moment mak',
#  'please try and take it easy dont want knock backwards ok end thanks',
#  'want die',
#  'brexiters leading economist saying run car industry remember nissan',
#  'god powerful satan must pray end evil befallen country must protest street',
#  'sometimes ever feel like everyone leaving u slowly and u cant even explain ure acting way hone',
#  'hospital car park see humanity broken weak and battered mended nervous and cured beginning',
#  'it badly team want it it ho hum ne never admit',
#  'yesterday made it year since nearly died hand abusive ex it something wish anyon',
#  'hate',
#  'know it nothing much first car purchase little speed civic something sma',
#  'saw it did manage light traffic sat roundabout nothing cab',
#  'supporting tweet supporting worthless piece shit failed life',
#  'im never going kill atm bc generally prefer live gym gonna burn sooner later',
#  'end hard day night life drive car please please something',
#  'every game asks replay game get additional content remember people stopped nier automaton',
#  'anyone buying anything better hope package get lost three month and counting',
#  'it fair and man fair nigeria want force nigeria kind president',
#  'fifteenth amendment granting black men right vote ratified day yet saw georgi',
#  'hate uh',
#  'it make sense want someone emotionally open hurt end',
#  'it new model it would high end version selling k b',
#  'put politics protecting country cause immeasurable pain million american stop f cking',
#  'want kill',
#  'ronaldo game hit goal reach goal end serie season gonna reach it',
#  'happy birthday glad gone life sweet genuine funny smart and se',
#  'cling tightly gun die kil',
#  'ebay shopping travel cosmetic makeup toiletry case wash organizer storage pouch hanging bag uk end date wed',
#  'nissan problem selling it new suv eu japan signed trade deal eu it got',
#  'long last wait it like week patch finished think find',
#  'mood going murder u it really end world know it',
#  'unexpected trip could end breaking ellie heart it first visit and yet it feel like going',
#  'hardest time often lead greatest moment life keep faith it worth it end',
#  'happens american medium give title like world series national league greatest dynasty',
#  ...]

# %%
preprocessed_data = pd.DataFrame(data=preprocessed_data,columns=['Transcript']) ##create dataframe of preprocessed data
preprocessed_data.shape
# Out:
# (8452, 1)

# %%
preprocessed_data.replace('',np.nan,inplace=True)
preprocessed_data
# Out:
#                                              Transcript
# 0     shattered chiromo mortuary and positively iden...
# 1     heading game chicken end game inevitable it be...
# 2     know else shit tech industry nothing designed ...
# 3     laverokbirdfood bluefrogtoys peacockspro jjeve...
# 4     reposting please refrain sharing video suicide...
# ...                                                 ...
# 8447  mister war serious business believe news ancho...
# 8448  woman dicmatized it nothing friend tell gone f...
# 8449  pakistan pm imran khan war world history misca...
# 8450  since pas law something already illegal nothin...
# 8451  trust regret it later one girl leave group it ...
#
# [8452 rows x 1 columns]

# %%
preprocessed_data['Class 1'] = df['Class 1'].values
preprocessed_data
# Out:
#                                              Transcript  Class 1
# 0     shattered chiromo mortuary and positively iden...        0
# 1     heading game chicken end game inevitable it be...        0
# 2     know else shit tech industry nothing designed ...        0
# 3     laverokbirdfood bluefrogtoys peacockspro jjeve...        0
# 4     reposting please refrain sharing video suicide...        0
# ...                                                 ...      ...
# 8447  mister war serious business believe news ancho...        0
# 8448  woman dicmatized it nothing friend tell gone f...        0
# 8449  pakistan pm imran khan war world history misca...        0
# 8450  since pas law something already illegal nothin...        0
# 8451  trust regret it later one girl leave group it ...        0
#
# [8452 rows x 2 columns]

# %%
preprocessed_data.isna().sum() ##check if the dataset contains NaN values
# Out:
# Transcript    2
# Class 1       0
# dtype: int64

# %%
preprocessed_data.dropna(inplace=True) ##drop NaN value
preprocessed_data.isna().sum()
# Out:
# Transcript    0
# Class 1       0
# dtype: int64

# %%
from pickle import dump
filename='preprocessed_data.pkl'
def save_preprocess_data(df,filename): ##Function to save the preprocessed data
    dump(df,open(filename,'wb'))
    print('Preprocessed data is saved :) :%s' % filename)  
save_preprocess_data(preprocessed_data,filename)
# Out:
# Preprocessed data is saved :) :preprocessed_data.pkl
